# %%
# Install packages
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
# Read file
#data_url = "https://storage.googleapis.com/covid19-open-data/v3/epidemiology.csv"
df_path  = (r'C:\Users\Lachu\Downloads\epidemiology.csv')
covid_df = pd.read_csv(df_path)

# %%
# Inspecting the dataframe - Data is messy in the real world. 

covid_df.shape    # Shape of the object (2D)
covid_df.dtypes   # Data types in each column
covid_df.columns  # Column names


covid_df.head()       # Displays first 5 rows
covid_df.tail()       # Displays last 5 rows
covid_df.sample()     # Displays a randow rows
covid_df.info()       # DataFrame information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12525825 entries, 0 to 12525824
# Data columns (total 10 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   date                  object
#  1   location_key          object
#  2   new_confirmed         float64
#  3   new_deceased          float64
#  4   new_recovered         float64
#  5   new_tested            float64
#  6   cumulative_confirmed  float64
#  7   cumulative_deceased   float64
#  8   cumulative_recovered  float64
#  9   cumulative_tested     float64
# dtypes: float64(8), object(2)
# memory usage: 955.6+ MB

# %%
# Subsetting a dataframe - by rows and columns (also cover multiple conditions - AND, OR)

denmark_covid_df = covid_df[covid_df['location_key']=="DK"]
india_covid_df = covid_df[covid_df['location_key']=="IN"]
covid_df.shape
print("Denmark", denmark_covid_df.shape)
print("India", india_covid_df.shape)

# Denmark + India

#dk_in_covid_df = covid_df[(covid_df['location_key']=="DK") | (covid_df['location_key']=="IN")]
dk_in_covid_df = covid_df[(covid_df['location_key']=="DK") & (covid_df['location_key']=="IN")]
dk_in_covid_df.shape
print("Denmark & India", dk_in_covid_df.shape)
# Out:
# Denmark (987, 10)
# India (987, 10)
# Denmark & India (0, 10)

# %%
# Assignment

# Section A
# 1. What is the number of unique values in the column "location_key"?

# 2. What's the earliest date for which the data has been collected for? And the latest date? 
# 3. On how many dates did we see the reported deaths greater than 100? 

# Section B
# Create a subset of the data satifying the following conditions 
# 1. All the data for the year 2021 only. 
# 2. Denmark, but only the data from 2020. 
# 3. India, but also all the dates where the new cases reported were more than 1000. 

# Section C
# 1. Subset the data to only include the following columns: "date","location_key","new_confirmed", "new_deceased", "new_recovered", "new_tested"
# 2. Add a new column to the dataset: The column should be named as "year" and should only contain the year part of the date, for each row. For example, if the "date" column has the value "2020-11-01" in row 1, then the "year" column for row 1 should contain the value "2020"

# Section D
# What are YOU curious to know from/about the dataset? Describe it in a simple statement, and how did you verify it? 
# What time of the year did you see the highest number of cases? and the location?
# What countries had maximum number of cases

# Duration between confirmation and

# %%
# 1. What is the number of unique values in the column "location_key"?
unique_values = covid_df['location_key'].unique
print(unique_values)
# Out:
# <bound method Series.unique of 0           AD
# 1           AD
# 2           AD
# 3           AD
# 4           AD
#             ..
# 12525820    ZW
# 12525821    ZW
# 12525822    ZW
# 12525823    ZW
# 12525824    ZW
# Name: location_key, Length: 12525825, dtype: object>

# %%
# 2. What's the earliest date for which the data has been collected for? And the latest date? 
earliest_date = covid_df['date'].min
print(earliest_date)
latest_date = covid_df['date'].max
print(latest_date)
# Out:
# <bound method Series.min of 0          2020-01-01
# 1          2020-01-02
# 2          2020-01-03
# 3          2020-01-04
# 4          2020-01-05
#               ...
# 12525820   2022-09-09
# 12525821   2022-09-10
# 12525822   2022-09-11
# 12525823   2022-09-12
# 12525824   2022-09-13
# Name: date, Length: 12525825, dtype: datetime64[ns]>
# <bound method Series.max of 0          2020-01-01
# 1          2020-01-02
# 2          2020-01-03
# 3          2020-01-04
# 4          2020-01-05
#               ...
# 12525820   2022-09-09
# 12525821   2022-09-10
# 12525822   2022-09-11
# 12525823   2022-09-12
# 12525824   2022-09-13
# Name: date, Length: 12525825, dtype: datetime64[ns]>

# %%
# On how many dates did we see the reported deaths greater than 100? 


death_over_100 = [covid_df[covid_df['new_deceased']>100]['date']]
num_deceased_more_than_100 = death_over_100['date'].nunique()
print(death_over_100)
print(num_deceased_more_than_100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 5
#       1 # On how many dates did we see the reported deaths greater than 100?
#       4 death_over_100 = [covid_df[covid_df['new_deceased']>100]['date']]
# ----> 5 num_deceased_more_than_100 = death_over_100['date'].nunique()
#       6 print(death_over_100)
#       7 print(num_deceased_more_than_100)
#
# TypeError: list indices must be integers or slices, not str

# %%
# All the data for the year 2021 only. 
#year_2021= [covid_df[covid_df['date'] ]
covid_df['date'] = pd.to_datetime(covid_df['date'])
covid_df['year'] = covid_df['date'].dt.year

# %%
covid_df
# Out:
#                date location_key  new_confirmed  new_deceased  new_recovered  \
# 0        2020-01-01           AD            0.0           0.0            NaN
# 1        2020-01-02           AD            0.0           0.0            NaN
# 2        2020-01-03           AD            0.0           0.0            NaN
# 3        2020-01-04           AD            0.0           0.0            NaN
# 4        2020-01-05           AD            0.0           0.0            NaN
# ...             ...          ...            ...           ...            ...
# 12525820 2022-09-09           ZW           11.0           0.0            NaN
# 12525821 2022-09-10           ZW           18.0           0.0            NaN
# 12525822 2022-09-11           ZW            0.0           0.0            NaN
# 12525823 2022-09-12           ZW           51.0           0.0            NaN
# 12525824 2022-09-13           ZW            0.0           0.0            NaN
#
# ...

# %%
year_2021 =[covid_df[covid_df['year']==2021]]
print(year_2021)

# %%
#2. Denmark, but only the data from 2020. 
denmark_2020 = covid_df[(covid_df['location_key']=='DK') & (covid_df['year']==2020)]
print(denmark_2020)
# Out:
#               date location_key  new_confirmed  new_deceased  new_recovered  \
# 6585013 2020-01-01           DK            0.0           0.0            NaN
# 6585014 2020-01-02           DK            0.0           0.0            NaN
# 6585015 2020-01-03           DK            0.0           0.0            NaN
# 6585016 2020-01-04           DK            0.0           0.0            NaN
# 6585017 2020-01-05           DK            0.0           0.0            NaN
# ...            ...          ...            ...           ...            ...
# 6585374 2020-12-27           DK         3062.0          29.0            NaN
# 6585375 2020-12-28           DK         2475.0          25.0            NaN
# 6585376 2020-12-29           DK         2768.0          32.0            NaN
# 6585377 2020-12-30           DK         1227.0          28.0            NaN
# 6585378 2020-12-31           DK         1203.0          33.0            NaN
#
# ...

# %%
 #India, but also all the dates where the new cases reported were more than 1000. 
india_2020 = covid_df[(covid_df['location_key']=='IN')&(covid_df['new_confirmed']>=1000)]
print(india_2020)
# Out:
#               date location_key  new_confirmed  new_deceased  new_recovered  \
# 7743126 2020-04-09           IN         1035.0          40.0            NaN
# 7743129 2020-04-12           IN         1211.0          31.0            NaN
# 7743130 2020-04-13           IN         1076.0          38.0            NaN
# 7743132 2020-04-15           IN         1007.0          23.0            NaN
# 7743134 2020-04-17           IN         1334.0          27.0            NaN
# ...            ...          ...            ...           ...            ...
# 7744009 2022-09-09           IN         5076.0          11.0            NaN
# 7744010 2022-09-10           IN         5221.0          15.0            NaN
# 7744011 2022-09-11           IN         4369.0          20.0            NaN
# 7744012 2022-09-12           IN         5108.0          31.0            NaN
# 7744013 2022-09-13           IN         6422.0          34.0            NaN
#
# ...

# %%
# Section C
# 1. Subset the data to only include the following columns: "date","location_key","new_confirmed", "new_deceased", "new_recovered", "new_tested"
covid_df[['date','location_key','new_confirmed', 'new_deceased', 'new_recovered', 'new_tested']]

# %%
# 2. Add a new column to the dataset: The column should be named as "year" and should only contain the year part of the date, for each row. For example, if the "date" column has the value "2020-11-01" in row 1, then the "year" column for row 1 should contain the value "2020"
covid_df['year'] = covid_df['date'].dt.year

# %%
covid_df['month'] = covid_df['date'].dt.month
covid_df
# Out:
#                date location_key  new_confirmed  new_deceased  new_recovered  \
# 0        2020-01-01           AD            0.0           0.0            NaN
# 1        2020-01-02           AD            0.0           0.0            NaN
# 2        2020-01-03           AD            0.0           0.0            NaN
# 3        2020-01-04           AD            0.0           0.0            NaN
# 4        2020-01-05           AD            0.0           0.0            NaN
# ...             ...          ...            ...           ...            ...
# 12525820 2022-09-09           ZW           11.0           0.0            NaN
# 12525821 2022-09-10           ZW           18.0           0.0            NaN
# 12525822 2022-09-11           ZW            0.0           0.0            NaN
# 12525823 2022-09-12           ZW           51.0           0.0            NaN
# 12525824 2022-09-13           ZW            0.0           0.0            NaN
#
# ...

# %% [markdown]
# # Section D
#  What are YOU curious to know from/about the dataset? Describe it in a simple statement, and how did you verify it? <br>
#  What time of the year did you see the more then 50th percentile of cases? and the location?<br>
#  countries with highest cases<br>
#  What time of the year did you see the highest number of cases? and the location?

# %%
print(covid_df['new_confirmed'].value_counts())
# Out:
# new_confirmed
# 0.0        5223189
# 1.0        1250591
# 2.0         685859
# 3.0         470648
# 4.0         357665
#             ...
# 14996.0          1
# 14406.0          1
# 21955.0          1
# 21605.0          1
# 13978.0          1
# Name: count, Length: 26183, dtype: int64

# %%
covid_df['new_confirmed'].skew()
# Out:
# np.float64(0.3380180998569549)

# %%
#max_new_confirmed = covid_df['new_confirmed'].max()
median_confirmed = covid_df['new_confirmed'].quantile(1/2)
print(median_confirmed)

higher_than_median= covid_df[covid_df['new_confirmed']>median_confirmed]
print(higher_than_median)
# Out:
# 1.0
#                date location_key  new_confirmed  new_deceased  new_recovered  \
# 74       2020-03-15           AD           12.0           0.0            NaN
# 75       2020-03-16           AD           25.0           0.0            NaN
# 77       2020-03-18           AD           36.0           0.0            NaN
# 78       2020-03-19           AD           19.0           0.0            NaN
# 79       2020-03-20           AD           39.0           1.0            NaN
# ...             ...          ...            ...           ...            ...
# 12525817 2022-09-06           ZW            9.0           0.0            NaN
# 12525819 2022-09-08           ZW           25.0           0.0            NaN
# 12525820 2022-09-09           ZW           11.0           0.0            NaN
# 12525821 2022-09-10           ZW           18.0           0.0            NaN
# 12525823 2022-09-12           ZW           51.0           0.0            NaN
#
# ...

# %%
covid_df['country'] = covid_df['location_key'].str.split('_').str[0]
covid_df
# Out:
#                date location_key  new_confirmed  new_deceased  new_recovered  \
# 0        2020-01-01           AD            0.0           0.0            NaN
# 1        2020-01-02           AD            0.0           0.0            NaN
# 2        2020-01-03           AD            0.0           0.0            NaN
# 3        2020-01-04           AD            0.0           0.0            NaN
# 4        2020-01-05           AD            0.0           0.0            NaN
# ...             ...          ...            ...           ...            ...
# 12525820 2022-09-09           ZW           11.0           0.0            NaN
# 12525821 2022-09-10           ZW           18.0           0.0            NaN
# 12525822 2022-09-11           ZW            0.0           0.0            NaN
# 12525823 2022-09-12           ZW           51.0           0.0            NaN
# 12525824 2022-09-13           ZW            0.0           0.0            NaN
#
# ...

# %%
covid_df['country'].describe()
# Out:
# count     12524838
# unique         232
# top             BR
# freq       5092413
# Name: country, dtype: object

# %%
# Group by year and month and sum of new confirmed
grouped_by_cases = covid_df.groupby(['year','month'])['new_confirmed'].sum()

print(grouped_by_cases)
# Out:
# year  month
# 2019  12               0.0
# 2020  1            54666.0
#       2          -141599.0
#       3          2195224.0
#       4          5900737.0
#       5          6952994.0
#       6         10523353.0
#       7         18846966.0
#       8         21267674.0
#       9         22948409.0
#       10        32110868.0
#       11        42206306.0
#       12        49425155.0
# 2021  1         50259467.0
#       2         27277331.0
#       3         36515608.0
#       4         55297748.0
#       5         50891567.0
#       6         28500422.0
#       7         35874256.0
#       8         44285163.0
#       9         35656059.0
#       10        26126334.0
#       11        37517690.0
#       12        70226267.0
# 2022  1        229694861.0
#       2        113546354.0
#       3         84933550.0
#       4         45288909.0
#       5         33905820.0
#       6         35307619.0
#       7         55101040.0
#       8         42081904.0
#       9         36642914.0
# ...

# %%
#countries with highest cases
highest_country = covid_df.groupby('country')['new_confirmed'].sum().sort_values(ascending=False)
highest_country.head(10)
#covid_df['cumulative_confirmed'] = covid_df.groupby('country')['new_confirmed'].sum()
#covid_df
# Out:
# country
# US    272244106.0
# IN    126463452.0
# BR    109948210.0
# GB     93263082.0
# FR     90395908.0
# IT     63645029.0
# DE     57763003.0
# NL     48677313.0
# JP     39752323.0
# RU     32572085.0
# Name: new_confirmed, dtype: float64

# %%
# import matplotlib.pyplot as plt

# # Get the top 10 countries
# top_countries = highest_contry.head(10)

# # Plot
# plt.figure(figsize=(12,6))
# top_countries.plot(kind='bar', color='coral', edgecolor='black')

# # Labels and title
# plt.xlabel("Country")
# plt.ylabel("Total Confirmed Cases")
# plt.title("Top 10 Countries with Highest COVID-19 Cases")
# plt.xticks(rotation=45)
# plt.grid(axis='y', linestyle='--', alpha=0.7)

# # Show plot
# plt.show()

# %%
# What time of the year did you see the highest number of cases? and the location?
highest_confirmed_row = covid_df.loc[covid_df['new_confirmed'].idxmax(), ['date', 'country', 'new_confirmed']]
print(highest_confirmed_row)
# Out:
# date             2022-06-07 00:00:00
# country                           NL
# new_confirmed              5047094.0
# Name: 8994738, dtype: object

# %%
#countries with most death
highest_death = covid_df.groupby('country')['new_deceased'].sum().sort_values(ascending=False)
highest_death.head(10)
#covid_df['cumulative_confirmed'] = covid_df.groupby('country')['new_confirmed'].sum()
#covid_df
# Out:
# country
# US    3055202.0
# BR    2220286.0
# IN    1501682.0
# RU     704849.0
# PE     625820.0
# GB     563941.0
# CO     476778.0
# DE     389150.0
# AR     379720.0
# MX     375972.0
# Name: new_deceased, dtype: float64

# %%
#countris with most recovered
highest_recovered = covid_df.groupby('country')['new_recovered'].sum().sort_values(ascending=False)
highest_recovered.head(10)
# Out:
# country
# FR    539574290.0
# IN     78532548.0
# IT     42987496.0
# BR     33706231.0
# DE     17977306.0
# CO     16323060.0
# AT     14816043.0
# ID     13977929.0
# CZ     12026149.0
# RU     10875781.0
# Name: new_recovered, dtype: float64

# %%
sum_newconfirmed = covid_df['new_confirmed'].sum()
print(sum_newconfirmed)
# Out:
# 1387190500.0

# %%
covid_df['Day_of_week'] = covid_df['date'].dt.day_of_week
mean_day_of_week = covid_df.groupby(['year'],['location_key']=='IN')['new_tested'].mean()
mean_day_of_week
# Out:
# C:\Users\Lachu\AppData\Local\Temp\ipykernel_25304\4063320147.py:2: FutureWarning: The 'axis' keyword in DataFrame.groupby is deprecated and will be removed in a future version.
#   mean_day_of_week = covid_df.groupby(['year'],['location_key']=='IN')['new_tested'].mean()
# year
# 2019      14.500000
# 2020    1322.773169
# 2021    2862.522537
# 2022    5171.860780
# Name: new_tested, dtype: float64

# %%
covid_df
# Out:
#                date location_key  new_confirmed  new_deceased  new_recovered  \
# 0        2020-01-01           AD            0.0           0.0            NaN
# 1        2020-01-02           AD            0.0           0.0            NaN
# 2        2020-01-03           AD            0.0           0.0            NaN
# 3        2020-01-04           AD            0.0           0.0            NaN
# 4        2020-01-05           AD            0.0           0.0            NaN
# ...             ...          ...            ...           ...            ...
# 12525820 2022-09-09           ZW           11.0           0.0            NaN
# 12525821 2022-09-10           ZW           18.0           0.0            NaN
# 12525822 2022-09-11           ZW            0.0           0.0            NaN
# 12525823 2022-09-12           ZW           51.0           0.0            NaN
# 12525824 2022-09-13           ZW            0.0           0.0            NaN
#
# ...

# %%
covid_df['mortality_rate_percentage'] = (covid_df['new_deceased']/covid_df['new_confirmed'])*100
covid_df['mortality_rate_percetage']= round(covid_df['mortality_rate_percentage'],2)
covid_df.sample(20)
# Out:
#                date  location_key  new_confirmed  new_deceased  new_recovered  \
# 6729553  2020-11-11   ES_CT_08126            3.0           NaN            NaN
# 279939   2021-05-18      AR_Q_014           17.0           0.0            NaN
# 469090   2022-05-23      AT_6_622           12.0           0.0           15.0
# 4317466  2022-01-28  BR_RS_430865            0.0           0.0            NaN
# 11554138 2021-01-03   US_OH_39083           36.0           0.0            NaN
# 3097399  2022-02-20  BR_PB_251540           23.0           0.0            NaN
# 4202959  2021-07-07  BR_RS_430235           15.0           1.0            0.0
# 11060055 2021-05-26   US_MO_29113           10.0           0.0            NaN
# 7989472  2021-01-03     IN_MH_AHN          117.0           1.0            2.0
# 9510861  2021-08-24      PL_14_23            0.0           0.0            NaN
# 10710727 2021-07-02   US_KY_21045            3.0           0.0            NaN
# ...

# %%
covid_df['new_confirmed'] =
